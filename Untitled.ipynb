# %%
## importing all important libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data_set = pd.read_csv(r"C:\Users\HP\Downloads\decision_tree.csv")

# %%
print(data_set.head())
print(data_set.info())
print(data_set.describe())
print(data_set.isnull().sum())
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510     NaN   19            19000          0
# 1  15810944     NaN   35            20000          0
# 2  15668575     NaN   26            43000          0
# 3  15603246     NaN   27            57000          0
# 4  15804002     NaN   19            76000          0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           0 non-null      float64
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: float64(1), int64(4)
# memory usage: 15.8 KB
# None
#             User ID  Gender         Age  EstimatedSalary   Purchased
# count  4.000000e+02     0.0  400.000000       400.000000  400.000000
# ...

# %%
data_set.head(5)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510     NaN   19            19000          0
# 1  15810944     NaN   35            20000          0
# 2  15668575     NaN   26            43000          0
# 3  15603246     NaN   27            57000          0
# 4  15804002     NaN   19            76000          0

# %%
##Exploitary data analysis(EDA)
sns.pairplot(data_set, hue='Purchased')
plt.savefig("Eda.png")
plt.show()

# %%
## correlation of features with target 
data_set['Gender'] = data_set['Gender'].map({'Male':1, 'Female':0})

sns.heatmap(data_set.corr(), annot=True)
plt.savefig("corr.png")
plt.show()

# %%
## separating independent and dependent variables
X = data_set.drop(['Purchased','User ID'],axis=1)
y = data_set['Purchased']

# %%
## train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 0)

# %%
##Scaling the features
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train)
X_test_sc = scaler.transform(X_test)

# %%
##training the model
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train_sc,y_train)
# Out:
# DecisionTreeClassifier()

# %%
##plotting decisiontree
from sklearn.tree import plot_tree

plt.figure(figsize=(10,6))
plot_tree(model, feature_names=X_train.columns, filled=True)
plt.savefig("DT_1.png")
plt.show()

# %%
##evaluation of 1st model
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
train1_acc = accuracy_score(y_train,model.predict(X_train_sc))
test1_acc = accuracy_score(y_test,model.predict(X_test_sc))

# %%
train1_acc
# Out:
# 1.0

# %%
test1_acc
# Out:
# 0.9125

# %%
cm = confusion_matrix(y_test,model.predict(X_test_sc))

# %%
cm
# Out:
# array([[53,  5],
#        [ 2, 20]])

# %%
cr_1 = classification_report(y_test,model.predict(X_test_sc))
print(cr_1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.94        58
#            1       0.80      0.91      0.85        22
#
#     accuracy                           0.91        80
#    macro avg       0.88      0.91      0.89        80
# weighted avg       0.92      0.91      0.91        80

# %%
## depth vs accuracy
depths = range(1, 10)
train_scores = []
test_scores = []

for d in depths:
    model = DecisionTreeClassifier(max_depth=d, random_state=0)
    model.fit(X_train_sc, y_train)
    
    train_scores.append(model.score(X_train_sc, y_train))
    test_scores.append(model.score(X_test_sc, y_test))

plt.plot(depths, train_scores, label="Train Accuracy")
plt.plot(depths, test_scores, label="Test Accuracy")
plt.xlabel("Tree Depth")
plt.ylabel("Accuracy")
plt.title("Overfitting Analysis")
plt.legend()
plt.savefig("Overfitting analysis.png")
plt.show()

# %%
## confustion matrix heatmap
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.savefig("cm_1.png")
plt.show()

# %%
## controlled model traininhttp://localhost:8888/notebooks/Linear%20Regression/Customer%20purchase%20prediction/Untitled.ipynb?#Controlled-Modelg
model_1 = DecisionTreeClassifier(
    criterion='entropy',
    max_depth=3,              
    random_state=0
)

model_1.fit(X_train_sc, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)

# %%
##plotting decisiontree
from sklearn.tree import plot_tree

plt.figure(figsize=(10,6))
plot_tree(model_1, feature_names=X_train.columns, filled=True)
plt.show()

# %%
## Evaluation
train2_acc = accuracy_score(y_train,model_1.predict(X_train_sc))

# %%
test2_acc = accuracy_score(y_test,model_1.predict(X_test_sc))

# %%
train2_acc
# Out:
# 0.909375

# %%
test2_acc
# Out:
# 0.95

# %%
cm_1 = confusion_matrix(y_test,model_1.predict(X_test_sc))
cm_1
# Out:
# array([[55,  3],
#        [ 1, 21]])

# %%
cr_2= classification_report(y_test,model_1.predict(X_test_sc))
print(cr_2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96        58
#            1       0.88      0.95      0.91        22
#
#     accuracy                           0.95        80
#    macro avg       0.93      0.95      0.94        80
# weighted avg       0.95      0.95      0.95        80

# %%
sns.heatmap(cm_1, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %% [markdown]
# ## Hyperparameter Tuning

# %%
## Hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'max_depth': [2,3,4,5],
    'min_samples_split': [2,5,10],
    'min_samples_leaf': [1,2,5]
}
grid = GridSearchCV(model,params,cv =10)
grid.fit(X_train_sc,y_train)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [2, 3, 4, 5],
#                          'min_samples_leaf': [1, 2, 5],
#                          'min_samples_split': [2, 5, 10]})

# %%
##plotting decisiontree
from sklearn.tree import plot_tree

plt.figure(figsize=(10,6))
plot_tree(model_1, feature_names=X_train.columns, filled=True)
plt.savefig("DT_2.png")
plt.show()

# %%
## Evaluation
grid.best_params_
# Out:
# {'max_depth': 2, 'min_samples_leaf': 1, 'min_samples_split': 2}

# %%
test3_acc = accuracy_score(y_test,grid.predict(X_test_sc))
test3_acc
# Out:
# 0.95

# %%
train3_acc = accuracy_score(y_train,grid.predict(X_train_sc))
train3_acc
# Out:
# 0.909375

# %%
cm_3 = confusion_matrix(y_test,grid.predict(X_test_sc))
cm_3
# Out:
# array([[55,  3],
#        [ 1, 21]])

# %%
cr_3 = classification_report(y_test,grid.predict(X_test_sc))
print(cr_1)
print(cr_2)
print(cr_3)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.91      0.94        58
#            1       0.80      0.91      0.85        22
#
#     accuracy                           0.91        80
#    macro avg       0.88      0.91      0.89        80
# weighted avg       0.92      0.91      0.91        80
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96        58
#            1       0.88      0.95      0.91        22
#
#     accuracy                           0.95        80
#    macro avg       0.93      0.95      0.94        80
# weighted avg       0.95      0.95      0.95        80
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.95      0.96        58
#            1       0.88      0.95      0.91        22
#
#     accuracy                           0.95        80
#    macro avg       0.93      0.95      0.94        80
# ...

# %%
feature_names = X_train.columns
importance = grid.best_estimator_.feature_importances_

plt.bar(feature_names, importance)
plt.title("Feature Importance")
plt.xlabel("Features")
plt.ylabel("Importance")
plt.savefig("feature importance.png")
plt.show()

# %%
sns.heatmap(cm_3, annot=True, fmt='d', cmap='Blues')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.savefig("cm_2.png")
plt.show()
